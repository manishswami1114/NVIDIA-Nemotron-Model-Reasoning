# %% [markdown]
# # Nemotron finetuning pipeline

# %%
# ── Shared config ─────────────────────────────────────────────────────
LORA_RANK = 32
LORA_ALPHA = 32
LORA_DROPOUT = 0.0

MAX_SEQ_LEN = 8192
NUM_STEPS = 1000
BATCH_SIZE = 32
MICRO_BATCH_SIZE = 4
LEARNING_RATE = 2e-4
RESET_WEIGHTS = (
    True  # if True, skip loading pretrained adapter; train from fresh LoRA init
)
IN_PROJ_ONLY = False
MOE_TIE_WEIGHTS = True  # if True, tie one side of MoE expert LoRA across all 128 experts (Tinker-style)
ORIGINAL_PROBLEMS_ONLY = (
    False  # if True, filter examples to only problem_ids listed in train.csv
)
SHUFFLE_DATASET = False

KAGGLE_DATASET = "huikang/nemotron-data"
MINUTES = 60

TARGET_MODULES = [
    "q_proj",
    "k_proj",
    "v_proj",
    "o_proj",
    "up_proj",
    "down_proj",
    "in_proj",
    "out_proj",
    "lm_head",
]

# ── Our training data ────────────────────────────────────────────────
CATEGORY_FILES = [
    "train_cot_bit_manipulation.jsonl",
    "train_cot_cipher.jsonl",
    "train_cot_cryptarithm_deduce.jsonl",
    "train_cot_cryptarithm_guess.jsonl",
    "train_cot_equation_numeric_deduce.jsonl",
    "train_cot_equation_numeric_guess.jsonl",
    "train_cot_gravity.jsonl",
    "train_cot_numeral.jsonl",
    "train_cot_unit_conversion.jsonl",
]

DATA_DIR_CANDIDATES = [
    "/kaggle/input/nemotron-categorical-splits",
    "/kaggle/input/nemotron-categorical-splits/all_categorical_splits",
    "/kaggle/input/all-categorical-splits",
    "/kaggle/input/all-categorical-splits/all_categorical_splits",
    "/kaggle/input/nemotron-cot-categorical/all_categorical_splits",
    "/kaggle/input/nemotron-cot-categorical",
]

# %%
import os

IS_KAGGLE = "KAGGLE_KERNEL_RUN_TYPE" in os.environ
IS_MODAL_WORKER = "MODAL_TASK_ID" in os.environ
IS_MODAL_LAUNCHER = not IS_KAGGLE and not IS_MODAL_WORKER

# %%
# ── Env-specific install (Kaggle only; Modal image has packages pre-installed) ──
if IS_KAGGLE:
    import subprocess

    subprocess.run(
        "pip install -q --no-index --find-links /kaggle/input/datasets/mayukh18/nemotron-packages/packages "
        "unsloth trl peft transformers datasets accelerate bitsandbytes",
        shell=True,
        check=True,
    )
    subprocess.run(
        "pip install -q /kaggle/input/datasets/mayukh18/nemotron-packages/causal_conv1d-1.6.1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl",
        shell=True,
        check=True,
    )
    subprocess.run(
        "pip install -q /kaggle/input/datasets/mayukh18/nemotron-packages/mamba_ssm-2.3.1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl",
        shell=True,
        check=True,
    )
    for _wd in ["/kaggle/input/datasets/llkh0a/rtx-wheels/wheels"]:
        if os.path.isdir(_wd):
            subprocess.run(
                [
                    "pip",
                    "install",
                    "-q",
                    "--no-index",
                    "--find-links",
                    _wd,
                    "protobuf==6.33.5",
                    "sentencepiece",
                    "safetensors",
                    "huggingface_hub",
                ],
                check=False,
            )
    subprocess.run("rm -rf /kaggle/tmp/*", shell=True, check=True)
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# s3fs 2026.2.0 requires fsspec==2026.2.0, but you have fsspec 2025.9.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.5 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.5 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.5 which is incompatible.

# %%
def run_training() -> None:
    """Full training flow. Runs on Kaggle at module level or inside Modal container via train_remote()."""
    import gc
    import json
    import math
    import random
    import subprocess
    import sys
    import time

    from unsloth import FastLanguageModel

    import torch
    from cut_cross_entropy import linear_cross_entropy
    from peft import LoraConfig
    from peft.tuners.lora import Linear as LoraLinear

    # ── Env-specific paths + adapter source ──────────────────────────
    if IS_KAGGLE:
        import kagglehub

        CORPUS_PATH = "/kaggle/input/datasets/huikang/huikang-nemotron-repository-snapshot/nemotron-master/training/sft/04-08-16-14/tokens"
        TRAIN_ORDER_PATH = "/kaggle/input/datasets/huikang/huikang-nemotron-repository-snapshot/nemotron-master/training/sft/04-08-16-14/logprobs/index.jsonl"
        TRAIN_CSV_PATH = "/kaggle/input/competitions/nvidia-nemotron-model-reasoning-challenge/train.csv"
        ADAPTER_SRC = "/kaggle/tmp/pretrained_adapter"
        if not RESET_WEIGHTS:
            import zipfile as _zipfile

            _adapter_zip = "/kaggle/input/notebooks/huikang/tinker-submission-notebook/submission.zip"
            os.makedirs(ADAPTER_SRC, exist_ok=True)
            with _zipfile.ZipFile(_adapter_zip, "r") as _zf:
                _zf.extractall(ADAPTER_SRC)
        MODEL_PATH = kagglehub.model_download(
            "metric/nemotron-3-nano-30b-a3b-bf16/transformers/default"
        )
    else:  # IS_MODAL_WORKER
        MODEL_PATH = "unsloth/Nemotron-3-Nano-30B-A3B"
        CORPUS_PATH = "/data/corpus_preprocessed.jsonl"
        TRAIN_CSV_PATH = "/data/train.csv"
        ADAPTER_SRC = "/merged/weights"
        OUTPUT_DIR = "/output/weights"

    # ── GPU + kernel sanity check (runs on both Kaggle and Modal worker) ──
    import causal_conv1d
    import mamba_ssm

    cc = torch.cuda.get_device_capability(0)
    print(f"GPU: {torch.cuda.get_device_name(0)}, sm_{cc[0] * 10 + cc[1]}")
    print(f"torch={torch.__version__}, cuda={torch.version.cuda}")
    print(
        f"mamba_ssm={mamba_ssm.__version__}, causal_conv1d={causal_conv1d.__version__}"
    )
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    if IS_MODAL_WORKER:
        assert cc == (12, 0), (
            f"Expected sm_120 (RTX PRO 6000), got sm_{cc[0] * 10 + cc[1]}"
        )
    from causal_conv1d import causal_conv1d_fn

    _x = torch.randn(1, 256, 32, device="cuda", dtype=torch.bfloat16)
    _w = torch.randn(256, 4, device="cuda", dtype=torch.bfloat16)
    causal_conv1d_fn(_x, _w, None, activation="silu")
    print("causal_conv1d CUDA kernel: OK")

    # Clear stale HF modules cache (Modal-only; bug: persists across runs)
    if IS_MODAL_WORKER:
        import shutil as _shutil

        hf_modules = os.path.join(
            os.environ.get("HF_HOME", "/root/.cache/huggingface"), "modules"
        )
        if os.path.exists(hf_modules):
            _shutil.rmtree(hf_modules)

    # ── Load corpus into `examples` list ─────────────────────────────
    examples: list[dict] = []

    if IS_KAGGLE:
        # ── Load OUR 9 category JSONLs (replaces huikang's pre-tokenized corpus) ──
        from transformers import AutoTokenizer
        _tok = AutoTokenizer.from_pretrained(MODEL_PATH, trust_remote_code=True)
        if _tok.pad_token is None:
            _tok.pad_token = _tok.eos_token

        # locate data dir
        _data_dir = None
        for _c in DATA_DIR_CANDIDATES:
            if _c and os.path.isdir(_c) and any(
                os.path.exists(os.path.join(_c, f)) for f in CATEGORY_FILES
            ):
                _data_dir = _c
                break
        assert _data_dir, f"no data dir found; searched: {DATA_DIR_CANDIDATES}"
        print(f"Data dir: {_data_dir}")

        # read all records
        _raw = []
        for _fname in CATEGORY_FILES:
            _fpath = os.path.join(_data_dir, _fname)
            if not os.path.exists(_fpath):
                print(f"  [skip] {_fname}")
                continue
            _cat = _fname.replace("train_cot_", "").replace(".jsonl", "")
            _n = 0
            with open(_fpath) as _f:
                for _line in _f:
                    if not _line.strip():
                        continue
                    _r = json.loads(_line)
                    _r.setdefault("category", _cat)
                    _raw.append(_r)
                    _n += 1
            print(f"  {_n:>5} from {_fname}")
        print(f"Total records: {len(_raw)}")

        # tokenize with response-only loss mask (mask=1 only on assistant tokens)
        _truncated = 0
        _skipped = 0
        for _rec in _raw:
            _msgs = [m for m in _rec["messages"] if m["role"] != "system"]
            if not _msgs or _msgs[-1]["role"] != "assistant":
                _skipped += 1
                continue
            _prompt_msgs = _msgs[:-1]
            try:
                _prompt_text = _tok.apply_chat_template(
                    _prompt_msgs, tokenize=False, add_generation_prompt=True
                )
                _full_text = _tok.apply_chat_template(
                    _msgs, tokenize=False, add_generation_prompt=False
                )
            except Exception:
                _prompt_text = (
                    f"<|im_start|>user\n{_prompt_msgs[0]['content']}<|im_end|>\n"
                    f"<|im_start|>assistant\n"
                )
                _full_text = _prompt_text + _msgs[-1]["content"] + "<|im_end|>"

            _prompt_ids = _tok(_prompt_text, add_special_tokens=False)["input_ids"]
            _full_ids   = _tok(_full_text,   add_special_tokens=False)["input_ids"]
            if len(_full_ids) <= len(_prompt_ids):
                _skipped += 1
                continue

            # tail-truncate (keep the answer, which is at the END of CoT)
            if len(_full_ids) > MAX_SEQ_LEN:
                _cut = len(_full_ids) - MAX_SEQ_LEN
                _full_ids = _full_ids[_cut:]
                _plen = max(0, len(_prompt_ids) - _cut)
                _truncated += 1
            else:
                _plen = len(_prompt_ids)

            _mask = [0] * _plen + [1] * (len(_full_ids) - _plen)
            if not any(_mask):
                _skipped += 1
                continue

            tokens  = _full_ids
            mask    = _mask
            examples.append(
                {
                    "problem_id": _rec.get("category", "unk") + "_" + str(len(examples)),
                    "tokens":  tokens[:-1],
                    "targets": tokens[1:],
                    "weights": [float(m) for m in mask[1:]],
                }
            )

        print(f"Built {len(examples)} examples (truncated={_truncated}, skipped={_skipped})")
    else:  # IS_MODAL_WORKER
        with open(CORPUS_PATH) as f:
            for line in f:
                rec = json.loads(line.strip())
                tokens = rec["tokens"]
                mask = rec["mask"]
                if len(tokens) > MAX_SEQ_LEN:
                    tokens = tokens[:MAX_SEQ_LEN]
                    mask = mask[:MAX_SEQ_LEN]
                if not any(mask):
                    continue
                examples.append(
                    {
                        "problem_id": rec["problem_id"],
                        "tokens": tokens[:-1],
                        "targets": tokens[1:],
                        "weights": [float(m) for m in mask[1:]],
                    }
                )

    if ORIGINAL_PROBLEMS_ONLY:
        import csv

        with open(TRAIN_CSV_PATH) as f:
            original_ids = {row["id"] for row in csv.DictReader(f)}
        before = len(examples)
        examples = [e for e in examples if e["problem_id"] in original_ids]
        print(
            f"ORIGINAL_PROBLEMS_ONLY=True: filtered {before} → {len(examples)} examples "
            f"using {len(original_ids)} ids from {TRAIN_CSV_PATH}"
        )

    total_unmasked = sum(sum(e["weights"]) for e in examples)
    total_tokens = sum(len(e["tokens"]) for e in examples)
    print(
        f"Loaded {len(examples)} examples, {total_tokens:,} tokens "
        f"(unmasked={total_unmasked:,.0f})"
    )

    # ── Load base model ──────────────────────────────────────────────
    gc.collect()
    torch.cuda.empty_cache()

    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=MODEL_PATH,
        max_seq_length=MAX_SEQ_LEN,
        load_in_4bit=False,
        load_in_8bit=False,
        full_finetuning=False,
        trust_remote_code=True,
        unsloth_force_compile=True,
        attn_implementation="eager",
        dtype=torch.bfloat16,
    )
    if IS_MODAL_WORKER:
        hf_cache_vol.commit()  # noqa: F821 — defined at module level on non-Kaggle

    # ── Wrap in LoRA ─────────────────────────────────────────────────
    model = FastLanguageModel.get_peft_model(
        model,
        r=LORA_RANK,
        target_modules=TARGET_MODULES,
        lora_alpha=LORA_ALPHA,
        lora_dropout=LORA_DROPOUT,
        bias="none",
        use_gradient_checkpointing="unsloth",
        random_state=42,
    )
    FastLanguageModel.for_training(model)

    # ── Patch Mamba CUDA fast path ───────────────────────────────────
    nemotron_mod = None
    for _name, _m in sys.modules.items():
        if "modeling_nemotron_h" in _name and hasattr(_m, "is_fast_path_available"):
            nemotron_mod = _m
            break
    assert nemotron_mod is not None, "Could not find modeling_nemotron_h module"
    print(f"is_fast_path_available was: {nemotron_mod.is_fast_path_available}")
    nemotron_mod.is_fast_path_available = True  # type: ignore[attr-defined]
    print("Patched is_fast_path_available = True")

    # ── Manually add lm_head LoRA (Unsloth drops it for MoE) ─────────
    _causal_lm = model
    while hasattr(_causal_lm, "model"):
        _causal_lm = _causal_lm.model
    _lm_head = _causal_lm.lm_head
    if not isinstance(_lm_head, LoraLinear):
        _cfg = LoraConfig(r=LORA_RANK, lora_alpha=LORA_ALPHA, lora_dropout=LORA_DROPOUT)
        model.base_model._create_and_replace(
            _cfg,
            "default",
            target=_lm_head,
            target_name="lm_head",
            parent=_causal_lm,
        )
        print("Manually added LoRA to lm_head")
    else:
        print("lm_head already has LoRA")

    # ── Cast LoRA params to fp32 (base model stays bf16 except MoE router) ──
    for name, param in model.named_parameters():
        if ".lora_" in name:
            param.data = param.data.to(torch.float32)

    for name, param in model.named_parameters():
        if ".lora_" in name:
            assert param.dtype == torch.float32, (
                f"LoRA param {name} expected fp32, got {param.dtype}"
            )
            continue

        is_router = (
            ".mixer.gate." in name
        )  # NemotronHTopkRouter.weight + e_score_correction_bias
        # Nemotron-H loads the MoE router (`mixer.gate`) in fp32 on purpose.
        # Ref: transformers/src/transformers/models/nemotron_h/modeling_nemotron_h.py
        #
        #   class NemotronHPreTrainedModel(PreTrainedModel):
        #       _keep_in_fp32_modules_strict = ["e_score_correction_bias"]
        #
        #   class NemotronHTopkRouter(nn.Module):
        #       def __init__(self, config):
        #           self.weight = nn.Parameter(torch.empty((self.n_routed_experts, config.hidden_size)))
        #           self.register_buffer("e_score_correction_bias", torch.zeros(self.n_routed_experts))
        #       def forward(self, hidden_states):
        #           router_logits = F.linear(
        #               hidden_states.type(torch.float32),
        #               self.weight.type(torch.float32),
        #           )
        #           return router_logits
        #
        # The per-forward fp32 cast on `self.weight` plus the strict list entry
        # mean the gate weight is promoted to fp32 at load time.
        if is_router:
            assert param.dtype == torch.float32, (
                f"param {name} expected fp32, got {param.dtype}"
            )
            continue

        assert param.dtype == torch.bfloat16, (
            f"param {name} expected bf16, got {param.dtype}"
        )
        continue

    print("Verified: LoRA params fp32, base params bf16 (MoE router fp32)")

    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    total = sum(p.numel() for p in model.parameters())
    print(f"Model: {trainable:,} trainable / {total:,} total parameters")

    # ── Patch forward with Cut Cross-Entropy ─────────────────────────
    _base = model
    while hasattr(_base, "model"):
        _base = _base.model

    def _patched_causal_forward(
        input_ids=None, attention_mask=None, labels=None, **kwargs
    ):
        backbone_out = _base.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask,
            **{
                k: v
                for k, v in kwargs.items()
                if k in ("position_ids", "past_key_values", "use_cache")
            },
        )
        hidden_states = backbone_out[0]
        lm_head = _base.lm_head
        base_w = lm_head.base_layer.weight
        lora_A = lm_head.lora_A["default"].weight
        lora_B = lm_head.lora_B["default"].weight
        scaling = lm_head.scaling["default"]
        lm_weight = base_w + scaling * lora_B @ lora_A
        if labels is not None:
            per_token_ce = linear_cross_entropy(
                hidden_states, lm_weight, labels, reduction="none"
            )
            loss = per_token_ce.mean()
        else:
            per_token_ce = None
            loss = None
        model._cached_per_token_ce = per_token_ce  # type: ignore[attr-defined]
        return loss

    _base.forward = _patched_causal_forward
    print("Patched CausalLM.forward with CCE (no logits materialization)")

    # ── Load adapter weights (unless RESET_WEIGHTS) ──────────────────
    if RESET_WEIGHTS:
        print(
            "RESET_WEIGHTS=True — skipping pretrained adapter load; using fresh LoRA init"
        )
        loaded = 0
        adapter_weights: dict = {}
    else:
        print(f"Loading adapter from {ADAPTER_SRC}...")
        from peft import load_peft_weights

        adapter_weights = load_peft_weights(ADAPTER_SRC)

        model_sd = model.state_dict()
        new_sd: dict = {}
        loaded = 0
        for ak, av in adapter_weights.items():
            if ak in model_sd:
                new_sd[ak] = av
                loaded += 1
                continue
            ak_with_default = ak.replace(
                ".lora_A.weight", ".lora_A.default.weight"
            ).replace(".lora_B.weight", ".lora_B.default.weight")
            if ak_with_default in model_sd:
                new_sd[ak_with_default] = av
                loaded += 1
                continue
            ak_lm = ak.replace(".backbone.lm_head.", ".lm_head.")
            ak_lm_default = ak_lm.replace(
                ".lora_A.weight", ".lora_A.default.weight"
            ).replace(".lora_B.weight", ".lora_B.default.weight")
            if ak_lm_default in model_sd:
                new_sd[ak_lm_default] = av
                loaded += 1
                continue

        model.load_state_dict(new_sd, strict=False)
        assert loaded == len(adapter_weights), (
            f"Not all adapter weights loaded: {loaded}/{len(adapter_weights)}"
        )
        print(f"  Loaded {loaded}/{len(adapter_weights)} weights into model")

    # ── Freeze all LoRA params except in_proj (if IN_PROJ_ONLY) ──
    print(f"{IN_PROJ_ONLY=}")
    if IN_PROJ_ONLY:
        for name, param in model.named_parameters():
            if param.requires_grad and ".in_proj." not in name:
                param.requires_grad = False
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    frozen_params = sum(p.numel() for p in model.parameters() if not p.requires_grad)
    print(f"  {trainable_params:,} trainable / {frozen_params:,} frozen")

    # ── MoE tied-weight params (Tinker convention) ───────────────────
    # Tinker ties whichever LoRA side touches the hidden dim:
    #   gate_up_proj / up_proj / w1 / gate_proj  -> tie A (input/hidden side)
    #   down_proj / w2                           -> tie B (output/hidden side)
    # We keep Unsloth's batched [num_experts, ...] tensor layout; "tying" means
    # all 128 expert slices are kept identical. Saving the adapter naturally
    # emits 128 per-expert copies, so submission.zip is untied downstream.
    moe_tied_params: list[torch.Tensor] = []
    if MOE_TIE_WEIGHTS:
        w1_proj_names = ("gate_up_proj", "up_proj", "gate_proj", ".w1.")
        w2_proj_names = ("down_proj", ".w2.")
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if ".experts." not in name or ".lora_" not in name:
                continue
            is_w1 = any(p in name for p in w1_proj_names)
            is_w2 = any(p in name for p in w2_proj_names)
            is_A = ".lora_A." in name
            is_B = ".lora_B." in name
            should_tie = (is_w1 and is_A) or (is_w2 and is_B)
            if not should_tie:
                continue
            if param.dim() < 2 or param.shape[0] <= 1:
                continue
            moe_tied_params.append(param)

        def _tie_param_init() -> None:
            """Make all 128 expert slices identical (mean-and-broadcast)."""
            with torch.no_grad():
                for p in moe_tied_params:
                    mean = p.data.mean(dim=0, keepdim=True)
                    p.data.copy_(mean.expand_as(p.data))

        def _tie_grads() -> None:
            # Sum (not mean) across the expert dim: if W is the shared LoRA factor
            # and each expert uses a copy W_i = W, chain rule gives
            # dL/dW = sum_i dL/dW_i. Inactive experts contribute 0 and router
            # weights are already baked into active g_i, so there's no
            # double-counting. Summing keeps all 128 slices identical after each
            # AdamW step and reproduces the true shared-weight update; mean would
            # be off by a 1/128 lr rescale (and not exactly equivalent under
            # AdamW's eps/weight-decay).
            with torch.no_grad():
                for p in moe_tied_params:
                    if p.grad is None:
                        continue
                    grad_sum = p.grad.sum(dim=0, keepdim=True)
                    p.grad.copy_(grad_sum.expand_as(p.grad))

        print(f"MoE weight tying: {len(moe_tied_params)} params identified for tying")
        if moe_tied_params:
            print(f"  example shapes: {[tuple(p.shape) for p in moe_tied_params[:3]]}")
        _tie_param_init()  # start from a tied state
    else:

        def _tie_grads() -> None:
            pass

    # ── Training loop ────────────────────────────────────────────────
    gc.collect()
    torch.cuda.empty_cache()

    device = next(model.parameters()).device
    optimizer: torch.optim.AdamW | None = None

    indices = list(range(len(examples)))
    if SHUFFLE_DATASET:
        rng = random.Random(0)
        rng.shuffle(indices)
        print(f"SHUFFLE_DATASET=True: shuffled {len(indices)} examples (seed=0)")
    else:
        print(f"SHUFFLE_DATASET=False: keeping corpus order ({len(indices)} examples)")

    training_log: list[str] = []

    def _log(msg: str) -> None:
        print(msg, flush=True)
        training_log.append(msg)

    max_steps = len(examples) // BATCH_SIZE
    num_steps = NUM_STEPS
    if num_steps > max_steps:
        _log(
            f"WARNING: NUM_STEPS={NUM_STEPS} exceeds max_steps={max_steps} "
            f"({len(examples)} examples // {BATCH_SIZE} batch). Clamping to {max_steps}."
        )
        num_steps = max_steps

    _log(
        f"Training: {num_steps} steps, batch_size={BATCH_SIZE}, "
        f"micro_batch_size={MICRO_BATCH_SIZE}, lr={LEARNING_RATE}"
    )

    step = 0
    for batch_start in range(0, len(indices), BATCH_SIZE):
        if step >= num_steps:
            break
        batch_indices = indices[batch_start : batch_start + BATCH_SIZE]
        batch = [examples[i] for i in batch_indices]
        batch_tokens = [e["tokens"] for e in batch]
        batch_targets = [e["targets"] for e in batch]
        batch_weights = [e["weights"] for e in batch]

        n = len(batch)
        n_accum = math.ceil(n / MICRO_BATCH_SIZE)
        total_loss_sum = 0.0
        total_weight_sum = 0.0

        for mb_start in range(0, n, MICRO_BATCH_SIZE):
            mb_end = min(mb_start + MICRO_BATCH_SIZE, n)
            mb_toks = batch_tokens[mb_start:mb_end]
            mb_tgts = batch_targets[mb_start:mb_end]
            mb_wts = batch_weights[mb_start:mb_end]

            n_micro = len(mb_toks)
            max_len = max(len(t) for t in mb_toks)
            total_len = sum(len(t) for t in mb_toks)

            padded_input = torch.zeros(
                n_micro, max_len, dtype=torch.long, device=device
            )
            padded_targets = torch.zeros(
                n_micro, max_len, dtype=torch.long, device=device
            )
            padded_weights = torch.zeros(
                n_micro, max_len, dtype=torch.float32, device=device
            )
            attention_mask = torch.zeros(
                n_micro, max_len, dtype=torch.long, device=device
            )
            for i in range(n_micro):
                seq_len = len(mb_toks[i])
                padded_input[i, :seq_len] = torch.tensor(mb_toks[i], dtype=torch.long)
                padded_targets[i, :seq_len] = torch.tensor(mb_tgts[i], dtype=torch.long)
                padded_weights[i, :seq_len] = torch.tensor(
                    mb_wts[i], dtype=torch.float32
                )
                attention_mask[i, :seq_len] = 1

            t0 = time.time()
            with torch.amp.autocast("cuda", dtype=torch.bfloat16):
                model(
                    input_ids=padded_input,
                    attention_mask=attention_mask,
                    labels=padded_targets,
                    use_cache=False,
                )
                per_token_ce = model._cached_per_token_ce  # type: ignore[attr-defined]
                weighted_loss = per_token_ce * padded_weights
                weight_sum_t = padded_weights.sum()
                loss_sum_t = weighted_loss.sum()
                loss = (
                    loss_sum_t / weight_sum_t if weight_sum_t > 0 else loss_sum_t * 0.0
                )

            (loss / n_accum).backward()
            total_loss_sum += loss_sum_t.item()
            total_weight_sum += weight_sum_t.item()
            del loss, per_token_ce, weighted_loss

            t_end = time.time()
            peak_gb = torch.cuda.max_memory_allocated() / 1e9
            mem_gb = torch.cuda.memory_allocated() / 1e9
            mb_idx = mb_start // MICRO_BATCH_SIZE
            print(
                f"    micro-batch {mb_idx}: {n_micro} seqs, max_len={max_len}, "
                f"total_len={total_len}, wall={t_end - t0:.1f}s, "
                f"peak={peak_gb:.1f}GB, mem={mem_gb:.1f}GB"
            )

        if optimizer is None:
            optimizer = torch.optim.AdamW(
                [p for p in model.parameters() if p.requires_grad],
                lr=LEARNING_RATE,
                betas=(0.9, 0.95),
                eps=1e-8,
                weight_decay=0.0,
            )
        lr = LEARNING_RATE * (1 - step / num_steps)
        for pg in optimizer.param_groups:
            pg["lr"] = lr
        _tie_grads()  # average MoE expert grads before clip+step so Adam stays in sync
        grad_norm = torch.nn.utils.clip_grad_norm_(
            [p for p in model.parameters() if p.requires_grad], max_norm=1e9
        )
        optimizer.step()
        optimizer.zero_grad()
        loss_mean = total_loss_sum / total_weight_sum if total_weight_sum > 0 else 0
        step += 1
        _log(
            f"  step {step}/{num_steps}: "
            f"loss:mean={loss_mean:.6f}, grad_norm={grad_norm:.4f}, lr={lr:.2e}"
        )

    print(
        f"\nTraining complete. Peak VRAM: {torch.cuda.max_memory_allocated() / 1e9:.1f} GB"
    )

    # ── Save adapter + rename lm_head keys (identical on both sides) ──
    from safetensors.torch import load_file, save_file

    save_dir = "." if IS_KAGGLE else OUTPUT_DIR
    os.makedirs(save_dir, exist_ok=True)
    for _f in os.listdir(save_dir):
        if _f.startswith("adapter"):
            os.remove(os.path.join(save_dir, _f))
    model.save_pretrained(save_dir)
    st_path = os.path.join(save_dir, "adapter_model.safetensors")
    tensors = load_file(st_path)
    renamed = {
        k.replace("base_model.model.lm_head.", "base_model.model.backbone.lm_head."): v
        for k, v in tensors.items()
    }
    save_file(renamed, st_path)

    # ── Clean unsloth compiled cache (runs on both) ──────────────────
    _ucache = "unsloth_compiled_cache"
    if os.path.isdir(_ucache):
        import shutil as _sh

        _sh.rmtree(_ucache)

    # ── Package & ship (divergent) ───────────────────────────────────
    if IS_KAGGLE:
        import zipfile

        adapter_files = [f for f in os.listdir(save_dir) if f.startswith("adapter")]
        SUBMISSION_ZIP = "submission.zip"
        with zipfile.ZipFile(SUBMISSION_ZIP, "w", zipfile.ZIP_DEFLATED) as zf:
            for fname in adapter_files:
                zf.write(os.path.join(save_dir, fname), fname)
        for fname in adapter_files:
            os.remove(os.path.join(save_dir, fname))
        print(f"Wrote {SUBMISSION_ZIP}")
    else:  # IS_MODAL_WORKER
        import shutil
        import tempfile

        with open(os.path.join(save_dir, "training_log.txt"), "w") as f:
            f.write("\n".join(training_log) + "\n")
        output_vol.commit()  # noqa: F821 — defined at module level on non-Kaggle

        kaggle_dir = os.path.expanduser("~/.kaggle")
        os.makedirs(kaggle_dir, exist_ok=True)
        with open(os.path.join(kaggle_dir, "access_token"), "w") as f:
            f.write(os.environ["KAGGLE_API_TOKEN"])
        upload_dir = tempfile.mkdtemp()
        for fname in os.listdir(save_dir):
            shutil.copy(os.path.join(save_dir, fname), upload_dir)
        metadata = {"id": KAGGLE_DATASET, "title": KAGGLE_DATASET.split("/")[1]}
        with open(os.path.join(upload_dir, "dataset-metadata.json"), "w") as f:
            json.dump(metadata, f)
        print(f"Uploading to Kaggle {KAGGLE_DATASET}...")
        subprocess.run(
            [
                "kaggle",
                "datasets",
                "version",
                "-p",
                upload_dir,
                "-m",
                "post-finetuned adapter + compiled wheels",
            ],
            check=True,
        )
        print("Kaggle upload complete.")
    print("Training complete.")

# %%
# ── Modal glue: image, app, volumes, train_remote, main ──────────────
# Defined at module level on non-Kaggle so the worker's module import
# registers train_remote with the app. On Kaggle, skipped entirely
# (modal package is not installed there).
if not IS_KAGGLE:
    import modal

    train_image = (
        modal.Image.from_registry(
            "nvidia/cuda:12.8.1-devel-ubuntu22.04",
            add_python="3.12",
        )
        .entrypoint([])
        .apt_install("git", "build-essential", "clang")
        .pip_install(
            "torch==2.10.0",
            extra_index_url="https://download.pytorch.org/whl/cu128",
        )
        .pip_install(
            "safetensors>=0.5.0",
            "transformers>=4.56.2",
            "accelerate>=1.0.0",
            "peft>=0.15.0",
            "bitsandbytes>=0.45.0",
            "huggingface_hub>=0.36.2",
            "hf-transfer>=0.1.9",
            "numpy",
            "pillow",
            "torchvision",
            "datasets",
            "sentencepiece",
            "xformers",
            "cut-cross-entropy>=25.1.0",
            "wheel",
            "setuptools",
            "trl",
            "kaggle>=1.6.0",
        )
        .run_commands(
            'python -c "import torch.utils.cpp_extension as e; p=e.__file__; '
            "t=open(p).read().replace('raise RuntimeError(CUDA_MISMATCH_MESSAGE', 'pass  # '); "
            "open(p,'w').write(t)\"",
            "TORCH_CUDA_ARCH_LIST='12.0' pip wheel --no-build-isolation --wheel-dir /wheels mamba_ssm==2.3.1 causal_conv1d==1.6.1",
            "pip install --no-deps /wheels/mamba_ssm-*.whl /wheels/causal_conv1d-*.whl",
            "pip install --no-deps 'unsloth_zoo[base] @ git+https://github.com/unslothai/unsloth-zoo'",
            "pip install --no-deps 'unsloth[base] @ git+https://github.com/unslothai/unsloth'",
        )
        .pip_install("einops")
        .env({"HF_HOME": "/root/.cache/huggingface"})
    )

    hf_cache_vol = modal.Volume.from_name("huggingface-cache", create_if_missing=True)
    merged_vol = modal.Volume.from_name("merged-adapter", create_if_missing=True)
    corpus_vol = modal.Volume.from_name("corpus-data", create_if_missing=True)
    output_vol = modal.Volume.from_name("post-finetune-output", create_if_missing=True)

    app = modal.App("post-finetune-pipeline")

    @app.function(
        image=train_image,
        gpu="RTX-PRO-6000",
        volumes={
            "/root/.cache/huggingface": hf_cache_vol,
            "/merged": merged_vol,
            "/data": corpus_vol,
            "/output": output_vol,
        },
        timeout=6 * 60 * MINUTES,
        secrets=[modal.Secret.from_local_environ(["KAGGLE_API_TOKEN"])],
    )
    def train_remote() -> None:
        run_training()

    if IS_MODAL_LAUNCHER:

        @app.local_entrypoint()
        def main() -> None:
            train_remote.remote()

# %%
# On Kaggle, trigger training directly after cells load.
# On Modal worker, Modal's runtime calls train_remote() which calls run_training().
# On Modal launcher, neither fires (main() submits the remote call instead).
if IS_KAGGLE:
    run_training()
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-04-25 04:51:52.380837: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777092712.581826      65 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777092712.637965      65 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777092713.171295      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777092713.171305      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777092713.171306      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777092713.171307      65 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition, sm_120
# torch=2.10.0+cu128, cuda=12.8
# mamba_ssm=2.3.1, causal_conv1d=1.6.1
# VRAM: 102.0 GB
# causal_conv1d CUDA kernel: OK
# Loaded 7830 problem_ids in training order from /kaggle/input/datasets/huikang/huikang-nemotron-repository-snapshot/nemotron-master/training/sft/04-08-16-14/logprobs/index.jsonl
# Loaded 7830 examples, 27,842,873 tokens (unmasked=26,568,807)
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.3.17: Fast Nemotron_H patching. Transformers: 4.57.6.
#    \\   /|    NVIDIA RTX PRO 6000 Blackwell Server Edition. Num GPUs = 1. Max memory: 94.971 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 12.0. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# Loading checkpoint shards:   0%|          | 0/13 [00:00<?, ?it/s]
# /kaggle/input/models/metric/nemotron-3-nano-30b-a3b-bf16/transformers/default/1 does not have a padding token! Will use pad_token = <SPECIAL_999>.
# Unsloth: Detected MoE model with num_experts = 128 and target_modules = ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'up_proj', 'down_proj', 'in_proj', 'out_proj', 'lm_head']. Enabling LoRA on MoE parameters: ['mlp.experts.gate_up_proj', 'mlp.experts.down_proj']
# Unsloth: PEFT set target_parameters but found no matching parameters.
# This is expected for MoE models - Unsloth handles MoE expert LoRA targeting separately.
# Unsloth: Making `model.base_model.model.backbone` require gradients
# is_fast_path_available was: True
# Patched is_fast_path_available = True
# lm_head already has LoRA
# Verified: LoRA params fp32, base params bf16 (MoE router fp32)
# Model: 888,154,112 trainable / 32,466,091,456 total parameters
# Patched CausalLM.forward with CCE (no logits materialization)
# RESET_WEIGHTS=True — skipping pretrained adapter load; using fresh LoRA init
# IN_PROJ_ONLY=False
#   888,154,112 trainable / 31,577,937,344 frozen
# MoE weight tying: 5888 params identified for tying
#   example shapes: [(32, 2688), (2688, 32), (32, 2688)]
# SHUFFLE_DATASET=False: keeping corpus order (7830 examples)
# WARNING: NUM_STEPS=1000 exceeds max_steps=244 (7830 examples // 32 batch). Clamping to 244.
# Training: 244 steps, batch_size=32, micro_batch_size=4, lr=0.0002
# Unsloth: Will smartly offload gradients to save VRAM!
#     micro-batch 0: 4 seqs, max_len=7605, total_len=17619, wall=61.9s, peak=79.7GB, mem=70.8GB
#     micro-batch 1: 4 seqs, max_len=3219, total_len=6436, wall=3.9s, peak=79.7GB, mem=70.6GB
#     micro-batch 2: 4 seqs, max_len=2876, total_len=6995, wall=5.3s, peak=79.7GB, mem=70.6GB
#     micro-batch 3: 4 seqs, max_len=6343, total_len=16369, wall=6.3s, peak=79.7GB, mem=70.7GB
#     micro-batch 4: 4 seqs, max_len=3833, total_len=9842, wall=4.4s, peak=79.7GB, mem=70.6GB
#     micro-batch 5: 4 seqs, max_len=6523, total_len=10686, wall=6.5s, peak=79.7GB, mem=70.7GB
#     micro-batch 6: 4 seqs, max_len=6688, total_len=17795, wall=10.6s, peak=79.7GB, mem=70.7GB
#     micro-batch 7: 4 seqs, max_len=6726, total_len=23384, wall=6.6s, peak=79.7GB, mem=70.7GB
#   step 1/244: loss:mean=0.385850, grad_norm=1.2333, lr=2.00e-04
#     micro-batch 0: 4 seqs, max_len=2338, total_len=6813, wall=3.2s, peak=81.3GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=6807, total_len=14018, wall=6.7s, peak=86.3GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6624, total_len=9087, wall=6.6s, peak=86.3GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7651, total_len=18704, wall=7.7s, peak=87.4GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=1981, total_len=5103, wall=3.5s, peak=87.4GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6924, total_len=13811, wall=6.8s, peak=87.4GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6569, total_len=16750, wall=6.5s, peak=87.4GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7372, total_len=12449, wall=7.1s, peak=87.4GB, mem=77.8GB
#   step 2/244: loss:mean=0.458810, grad_norm=1.2510, lr=1.99e-04
#     micro-batch 0: 4 seqs, max_len=6182, total_len=8546, wall=6.2s, peak=87.4GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7630, total_len=19114, wall=7.3s, peak=87.4GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6877, total_len=16536, wall=6.7s, peak=87.4GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6204, total_len=17256, wall=7.3s, peak=87.4GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7363, total_len=17396, wall=7.1s, peak=87.4GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7645, total_len=25312, wall=7.3s, peak=87.4GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6617, total_len=20730, wall=6.5s, peak=87.4GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6348, total_len=17412, wall=6.3s, peak=87.4GB, mem=77.8GB
#   step 3/244: loss:mean=0.368971, grad_norm=0.6772, lr=1.98e-04
#     micro-batch 0: 4 seqs, max_len=6488, total_len=20004, wall=6.4s, peak=87.4GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7232, total_len=13830, wall=7.0s, peak=87.4GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6249, total_len=17904, wall=6.2s, peak=87.4GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7520, total_len=22204, wall=7.2s, peak=87.4GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7217, total_len=16365, wall=7.8s, peak=87.4GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3041, total_len=9178, wall=3.8s, peak=87.4GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=7082, total_len=12594, wall=6.9s, peak=87.4GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7246, total_len=20983, wall=7.0s, peak=87.4GB, mem=77.8GB
#   step 4/244: loss:mean=0.304229, grad_norm=0.5325, lr=1.98e-04
#     micro-batch 0: 4 seqs, max_len=1110, total_len=4268, wall=2.8s, peak=87.4GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7673, total_len=20537, wall=7.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6258, total_len=10741, wall=6.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6384, total_len=16882, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7532, total_len=17483, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6463, total_len=11278, wall=6.5s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7206, total_len=21866, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=1105, total_len=3441, wall=2.8s, peak=87.5GB, mem=77.6GB
#   step 5/244: loss:mean=0.330424, grad_norm=0.6889, lr=1.97e-04
#     micro-batch 0: 4 seqs, max_len=6676, total_len=14836, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7416, total_len=15072, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=2215, total_len=6100, wall=3.2s, peak=87.5GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6363, total_len=16451, wall=6.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6748, total_len=12721, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6885, total_len=13329, wall=6.8s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3480, total_len=9335, wall=4.1s, peak=87.5GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7005, total_len=13834, wall=6.8s, peak=87.5GB, mem=77.8GB
#   step 6/244: loss:mean=0.289819, grad_norm=0.6260, lr=1.96e-04
#     micro-batch 0: 4 seqs, max_len=7285, total_len=16009, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7378, total_len=14455, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7244, total_len=18131, wall=7.0s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=4084, total_len=9002, wall=4.9s, peak=87.5GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=3679, total_len=9648, wall=4.3s, peak=87.5GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=5739, total_len=9476, wall=5.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7337, total_len=16733, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7545, total_len=17061, wall=7.2s, peak=87.5GB, mem=77.8GB
#   step 7/244: loss:mean=0.281092, grad_norm=0.6457, lr=1.95e-04
#     micro-batch 0: 4 seqs, max_len=7552, total_len=16135, wall=7.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7064, total_len=17538, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4143, total_len=11441, wall=4.6s, peak=87.5GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=2785, total_len=5538, wall=4.6s, peak=87.5GB, mem=77.6GB
#     micro-batch 4: 4 seqs, max_len=2981, total_len=5458, wall=3.8s, peak=87.5GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6822, total_len=17047, wall=6.7s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6652, total_len=14608, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5922, total_len=10093, wall=6.0s, peak=87.5GB, mem=77.8GB
#   step 8/244: loss:mean=0.252117, grad_norm=0.6169, lr=1.94e-04
#     micro-batch 0: 4 seqs, max_len=6154, total_len=12819, wall=6.2s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6635, total_len=19159, wall=6.5s, peak=87.5GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7584, total_len=25365, wall=7.3s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7043, total_len=12493, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7083, total_len=14434, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7124, total_len=16666, wall=6.9s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=2628, total_len=9959, wall=3.5s, peak=87.5GB, mem=77.6GB
#     micro-batch 7: 4 seqs, max_len=6833, total_len=14045, wall=6.7s, peak=87.5GB, mem=77.8GB
#   step 9/244: loss:mean=0.227502, grad_norm=0.6456, lr=1.93e-04
#     micro-batch 0: 4 seqs, max_len=2619, total_len=6152, wall=3.5s, peak=87.5GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=2802, total_len=9106, wall=3.7s, peak=87.5GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6680, total_len=15008, wall=6.6s, peak=87.5GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6832, total_len=13922, wall=6.7s, peak=87.5GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5677, total_len=14172, wall=5.8s, peak=87.5GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6488, total_len=21403, wall=6.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6460, total_len=14597, wall=6.4s, peak=87.5GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6601, total_len=16447, wall=6.5s, peak=87.5GB, mem=77.8GB
#   step 10/244: loss:mean=0.219638, grad_norm=0.5968, lr=1.93e-04
#     micro-batch 0: 4 seqs, max_len=7331, total_len=16441, wall=7.1s, peak=87.5GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7855, total_len=28382, wall=7.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=2495, total_len=7297, wall=3.4s, peak=87.7GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=7225, total_len=18014, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2835, total_len=8920, wall=3.7s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=7217, total_len=20417, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6999, total_len=16680, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5807, total_len=19707, wall=5.9s, peak=87.7GB, mem=77.8GB
#   step 11/244: loss:mean=0.220394, grad_norm=0.5650, lr=1.92e-04
#     micro-batch 0: 4 seqs, max_len=6758, total_len=17835, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6627, total_len=16924, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6416, total_len=12954, wall=6.4s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7388, total_len=20651, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6166, total_len=13607, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6611, total_len=13516, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6343, total_len=21164, wall=6.3s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5677, total_len=12795, wall=5.8s, peak=87.7GB, mem=77.8GB
#   step 12/244: loss:mean=0.175845, grad_norm=0.5014, lr=1.91e-04
#     micro-batch 0: 4 seqs, max_len=7396, total_len=20077, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7188, total_len=15874, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3309, total_len=9337, wall=4.0s, peak=87.7GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7032, total_len=17762, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7454, total_len=15859, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7388, total_len=18225, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3589, total_len=10056, wall=4.2s, peak=87.7GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=2544, total_len=9035, wall=3.5s, peak=87.7GB, mem=77.6GB
#   step 13/244: loss:mean=0.181369, grad_norm=0.5334, lr=1.90e-04
#     micro-batch 0: 4 seqs, max_len=5482, total_len=11858, wall=5.7s, peak=87.7GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=3340, total_len=9090, wall=4.0s, peak=87.7GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=7171, total_len=18463, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=2187, total_len=5613, wall=3.2s, peak=87.7GB, mem=77.6GB
#     micro-batch 4: 4 seqs, max_len=5503, total_len=10550, wall=5.7s, peak=87.7GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=5909, total_len=12753, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=2271, total_len=5743, wall=3.3s, peak=87.7GB, mem=77.6GB
#     micro-batch 7: 4 seqs, max_len=5876, total_len=13866, wall=6.0s, peak=87.7GB, mem=77.8GB
#   step 14/244: loss:mean=0.136631, grad_norm=0.5334, lr=1.89e-04
#     micro-batch 0: 4 seqs, max_len=6748, total_len=18509, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6726, total_len=16850, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6885, total_len=16316, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6180, total_len=16116, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2710, total_len=8199, wall=3.6s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=7250, total_len=23166, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7194, total_len=22030, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7245, total_len=18876, wall=7.0s, peak=87.7GB, mem=77.8GB
#   step 15/244: loss:mean=0.159434, grad_norm=0.4941, lr=1.89e-04
#     micro-batch 0: 4 seqs, max_len=2226, total_len=6752, wall=3.2s, peak=87.7GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7565, total_len=17571, wall=7.3s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3200, total_len=10304, wall=3.9s, peak=87.7GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=7401, total_len=19219, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7220, total_len=20876, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=2551, total_len=7972, wall=3.5s, peak=87.7GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=6877, total_len=16279, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2217, total_len=6898, wall=3.3s, peak=87.7GB, mem=77.6GB
#   step 16/244: loss:mean=0.135320, grad_norm=0.7083, lr=1.88e-04
#     micro-batch 0: 4 seqs, max_len=7119, total_len=17786, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7064, total_len=15848, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7146, total_len=13434, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7191, total_len=20564, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6198, total_len=13292, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7316, total_len=14069, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6055, total_len=12127, wall=6.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5675, total_len=10247, wall=5.8s, peak=87.7GB, mem=77.8GB
#   step 17/244: loss:mean=0.119851, grad_norm=0.4205, lr=1.87e-04
#     micro-batch 0: 4 seqs, max_len=6672, total_len=10770, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7477, total_len=20975, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6965, total_len=22269, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7471, total_len=23551, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5957, total_len=11899, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7092, total_len=16386, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7076, total_len=11991, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6855, total_len=17234, wall=6.7s, peak=87.7GB, mem=77.8GB
#   step 18/244: loss:mean=0.128247, grad_norm=0.4762, lr=1.86e-04
#     micro-batch 0: 4 seqs, max_len=3686, total_len=8529, wall=5.2s, peak=87.7GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6855, total_len=17614, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6864, total_len=17149, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6468, total_len=13627, wall=6.4s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6857, total_len=19099, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3680, total_len=9805, wall=4.3s, peak=87.7GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=2319, total_len=5382, wall=3.3s, peak=87.7GB, mem=77.6GB
#     micro-batch 7: 4 seqs, max_len=3940, total_len=11931, wall=4.4s, peak=87.7GB, mem=77.7GB
#   step 19/244: loss:mean=0.089433, grad_norm=0.4323, lr=1.85e-04
#     micro-batch 0: 4 seqs, max_len=2125, total_len=7350, wall=3.2s, peak=87.7GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7199, total_len=23812, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4264, total_len=9213, wall=4.7s, peak=87.7GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6168, total_len=13794, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2984, total_len=9292, wall=3.8s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=2443, total_len=6024, wall=3.4s, peak=87.7GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=6874, total_len=17157, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7180, total_len=16840, wall=7.0s, peak=87.7GB, mem=77.8GB
#   step 20/244: loss:mean=0.086330, grad_norm=0.4427, lr=1.84e-04
#     micro-batch 0: 4 seqs, max_len=6333, total_len=16529, wall=6.3s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6407, total_len=10984, wall=6.4s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6182, total_len=14939, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=3433, total_len=6604, wall=4.1s, peak=87.7GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=2981, total_len=8816, wall=3.8s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=5919, total_len=12576, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6909, total_len=11836, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2524, total_len=4905, wall=3.4s, peak=87.7GB, mem=77.6GB
#   step 21/244: loss:mean=0.073553, grad_norm=0.4211, lr=1.84e-04
#     micro-batch 0: 4 seqs, max_len=2645, total_len=9047, wall=3.5s, peak=87.7GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7025, total_len=19381, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6814, total_len=17636, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7597, total_len=23945, wall=7.3s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2450, total_len=8962, wall=3.4s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6793, total_len=16263, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7255, total_len=15628, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5505, total_len=13820, wall=5.7s, peak=87.7GB, mem=77.7GB
#   step 22/244: loss:mean=0.071533, grad_norm=0.3438, lr=1.83e-04
#     micro-batch 0: 4 seqs, max_len=2890, total_len=6955, wall=3.7s, peak=87.7GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7025, total_len=14505, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6542, total_len=12853, wall=6.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7102, total_len=23672, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7253, total_len=19446, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=4196, total_len=10437, wall=4.6s, peak=87.7GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6615, total_len=13334, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6224, total_len=12044, wall=6.3s, peak=87.7GB, mem=77.8GB
#   step 23/244: loss:mean=0.066468, grad_norm=0.3421, lr=1.82e-04
#     micro-batch 0: 4 seqs, max_len=2437, total_len=7184, wall=3.4s, peak=87.7GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7243, total_len=16674, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3263, total_len=8298, wall=4.0s, peak=87.7GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6164, total_len=11907, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6784, total_len=20286, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6895, total_len=14722, wall=7.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7768, total_len=11445, wall=7.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2904, total_len=7650, wall=3.7s, peak=87.7GB, mem=77.6GB
#   step 24/244: loss:mean=0.062029, grad_norm=0.3537, lr=1.81e-04
#     micro-batch 0: 4 seqs, max_len=6671, total_len=18267, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2298, total_len=8267, wall=3.3s, peak=87.7GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6433, total_len=16805, wall=6.4s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6702, total_len=15728, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7180, total_len=13473, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7272, total_len=13617, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6753, total_len=10216, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6962, total_len=16308, wall=6.8s, peak=87.7GB, mem=77.8GB
#   step 25/244: loss:mean=0.053777, grad_norm=0.3907, lr=1.80e-04
#     micro-batch 0: 4 seqs, max_len=2668, total_len=9490, wall=3.5s, peak=87.7GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7011, total_len=22366, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6979, total_len=15994, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6209, total_len=16352, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6449, total_len=14722, wall=6.4s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5465, total_len=9525, wall=5.7s, peak=87.7GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=7313, total_len=11862, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6621, total_len=15520, wall=6.6s, peak=87.7GB, mem=77.8GB
#   step 26/244: loss:mean=0.044162, grad_norm=0.3842, lr=1.80e-04
#     micro-batch 0: 4 seqs, max_len=5495, total_len=10738, wall=5.7s, peak=87.7GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=7444, total_len=19464, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6907, total_len=17808, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7346, total_len=16726, wall=7.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2133, total_len=5413, wall=3.2s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6465, total_len=11542, wall=6.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6970, total_len=13633, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7036, total_len=15460, wall=6.9s, peak=87.7GB, mem=77.8GB
#   step 27/244: loss:mean=0.040221, grad_norm=0.3839, lr=1.79e-04
#     micro-batch 0: 4 seqs, max_len=6733, total_len=10595, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6654, total_len=12965, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6783, total_len=15666, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6550, total_len=13047, wall=6.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7122, total_len=18847, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7525, total_len=17688, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6684, total_len=21110, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7006, total_len=14238, wall=6.8s, peak=87.7GB, mem=77.8GB
#   step 28/244: loss:mean=0.038536, grad_norm=0.5708, lr=1.78e-04
#     micro-batch 0: 4 seqs, max_len=3699, total_len=11704, wall=4.2s, peak=87.7GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6061, total_len=11937, wall=6.1s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6645, total_len=14117, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7513, total_len=15092, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7240, total_len=15009, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6624, total_len=14404, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6709, total_len=17137, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3603, total_len=6961, wall=4.2s, peak=87.7GB, mem=77.7GB
#   step 29/244: loss:mean=0.028758, grad_norm=0.5197, lr=1.77e-04
#     micro-batch 0: 4 seqs, max_len=6161, total_len=17141, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2508, total_len=8881, wall=4.4s, peak=87.7GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=7072, total_len=18702, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7453, total_len=18916, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3843, total_len=9965, wall=4.4s, peak=87.7GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=2364, total_len=6355, wall=3.3s, peak=87.7GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=6296, total_len=15587, wall=6.3s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6488, total_len=20471, wall=6.4s, peak=87.7GB, mem=77.8GB
#   step 30/244: loss:mean=0.025124, grad_norm=0.2599, lr=1.76e-04
#     micro-batch 0: 4 seqs, max_len=7131, total_len=17553, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5754, total_len=11369, wall=5.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7047, total_len=12461, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7011, total_len=19611, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5967, total_len=14715, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6232, total_len=12173, wall=6.3s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6953, total_len=13428, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2405, total_len=7524, wall=3.4s, peak=87.7GB, mem=77.6GB
#   step 31/244: loss:mean=0.022157, grad_norm=0.2829, lr=1.75e-04
#     micro-batch 0: 4 seqs, max_len=5998, total_len=15480, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6873, total_len=12228, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=2202, total_len=7342, wall=3.2s, peak=87.7GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6121, total_len=14558, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7250, total_len=15750, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6568, total_len=12460, wall=6.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7213, total_len=17809, wall=7.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6405, total_len=15854, wall=6.4s, peak=87.7GB, mem=77.8GB
#   step 32/244: loss:mean=0.021654, grad_norm=0.2885, lr=1.75e-04
#     micro-batch 0: 4 seqs, max_len=7009, total_len=17338, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6916, total_len=21732, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7485, total_len=23420, wall=7.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7032, total_len=16364, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4762, total_len=12071, wall=5.1s, peak=87.7GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6561, total_len=18066, wall=6.5s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7140, total_len=20448, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5670, total_len=10752, wall=5.8s, peak=87.7GB, mem=77.8GB
#   step 33/244: loss:mean=0.022954, grad_norm=0.2729, lr=1.74e-04
#     micro-batch 0: 4 seqs, max_len=3509, total_len=11079, wall=4.1s, peak=87.7GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=2761, total_len=8460, wall=3.6s, peak=87.7GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6903, total_len=17208, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6182, total_len=20929, wall=6.2s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2863, total_len=7578, wall=3.7s, peak=87.7GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=6985, total_len=21010, wall=6.9s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6998, total_len=18176, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5513, total_len=13034, wall=5.7s, peak=87.7GB, mem=77.7GB
#   step 34/244: loss:mean=0.017504, grad_norm=0.2296, lr=1.73e-04
#     micro-batch 0: 4 seqs, max_len=6909, total_len=15461, wall=6.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5919, total_len=13174, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5948, total_len=11841, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5834, total_len=12211, wall=6.0s, peak=87.7GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6650, total_len=13788, wall=6.6s, peak=87.7GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6869, total_len=17600, wall=7.7s, peak=87.7GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3462, total_len=9323, wall=4.1s, peak=87.7GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=6877, total_len=14930, wall=6.8s, peak=87.7GB, mem=77.8GB
#   step 35/244: loss:mean=0.012941, grad_norm=0.1957, lr=1.72e-04
#     micro-batch 0: 4 seqs, max_len=5733, total_len=13684, wall=5.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6901, total_len=20144, wall=6.8s, peak=87.7GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7970, total_len=20112, wall=7.6s, peak=87.9GB, mem=77.9GB
#     micro-batch 3: 4 seqs, max_len=2069, total_len=6069, wall=3.2s, peak=87.9GB, mem=77.6GB
#     micro-batch 4: 4 seqs, max_len=7172, total_len=16919, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7587, total_len=19726, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6204, total_len=14682, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3537, total_len=9810, wall=4.2s, peak=87.9GB, mem=77.7GB
#   step 36/244: loss:mean=0.017025, grad_norm=0.1979, lr=1.71e-04
#     micro-batch 0: 4 seqs, max_len=7386, total_len=14720, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6272, total_len=11798, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=2840, total_len=5708, wall=3.7s, peak=87.9GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6815, total_len=13172, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5981, total_len=13333, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7021, total_len=19369, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6581, total_len=20023, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2141, total_len=5532, wall=3.2s, peak=87.9GB, mem=77.6GB
#   step 37/244: loss:mean=0.014184, grad_norm=0.2437, lr=1.70e-04
#     micro-batch 0: 4 seqs, max_len=3276, total_len=8676, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6658, total_len=13052, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3063, total_len=8861, wall=3.8s, peak=87.9GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=7443, total_len=16709, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5771, total_len=10933, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6653, total_len=13756, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6559, total_len=20511, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7489, total_len=21906, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 38/244: loss:mean=0.012184, grad_norm=0.1610, lr=1.70e-04
#     micro-batch 0: 4 seqs, max_len=7277, total_len=18869, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5922, total_len=12671, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7372, total_len=13680, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7196, total_len=23607, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7377, total_len=13316, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7151, total_len=12772, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3634, total_len=8300, wall=4.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7331, total_len=21138, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 39/244: loss:mean=0.012290, grad_norm=0.1573, lr=1.69e-04
#     micro-batch 0: 4 seqs, max_len=5908, total_len=14194, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5974, total_len=16486, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5716, total_len=11350, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6981, total_len=21261, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6017, total_len=13684, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6624, total_len=14848, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7598, total_len=13436, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5971, total_len=12992, wall=6.0s, peak=87.9GB, mem=77.8GB
#   step 40/244: loss:mean=0.007893, grad_norm=0.1345, lr=1.68e-04
#     micro-batch 0: 4 seqs, max_len=6942, total_len=13642, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7135, total_len=9275, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7459, total_len=23496, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7353, total_len=23410, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6646, total_len=22827, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7033, total_len=14037, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6905, total_len=15061, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5655, total_len=12233, wall=5.8s, peak=87.9GB, mem=77.8GB
#   step 41/244: loss:mean=0.013506, grad_norm=0.2000, lr=1.67e-04
#     micro-batch 0: 4 seqs, max_len=6041, total_len=15167, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7301, total_len=24238, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7444, total_len=22507, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7401, total_len=16267, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2520, total_len=5819, wall=3.4s, peak=87.9GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=2959, total_len=9447, wall=3.8s, peak=87.9GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=7126, total_len=11454, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7606, total_len=21361, wall=7.3s, peak=87.9GB, mem=77.8GB
#   step 42/244: loss:mean=0.009397, grad_norm=0.1635, lr=1.66e-04
#     micro-batch 0: 4 seqs, max_len=7304, total_len=12748, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6789, total_len=15421, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7690, total_len=13311, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=3853, total_len=10668, wall=4.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=3284, total_len=7453, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=7317, total_len=15694, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7771, total_len=21875, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7459, total_len=23479, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 43/244: loss:mean=0.008541, grad_norm=0.1352, lr=1.66e-04
#     micro-batch 0: 4 seqs, max_len=7415, total_len=26248, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7477, total_len=14770, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7261, total_len=11232, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7278, total_len=20498, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6912, total_len=12339, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7378, total_len=23966, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=2446, total_len=7719, wall=3.4s, peak=87.9GB, mem=77.6GB
#     micro-batch 7: 4 seqs, max_len=7499, total_len=14902, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 44/244: loss:mean=0.011772, grad_norm=0.1778, lr=1.65e-04
#     micro-batch 0: 4 seqs, max_len=7783, total_len=17901, wall=7.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6830, total_len=10748, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7054, total_len=18344, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7210, total_len=16054, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7236, total_len=19123, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5060, total_len=12327, wall=5.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=7633, total_len=16368, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2613, total_len=7777, wall=3.5s, peak=87.9GB, mem=77.6GB
#   step 45/244: loss:mean=0.008145, grad_norm=0.1484, lr=1.64e-04
#     micro-batch 0: 4 seqs, max_len=6639, total_len=12126, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7311, total_len=19574, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6911, total_len=15220, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5808, total_len=14147, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6116, total_len=11788, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5651, total_len=11020, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6749, total_len=15443, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6680, total_len=15380, wall=6.6s, peak=87.9GB, mem=77.8GB
#   step 46/244: loss:mean=0.007820, grad_norm=0.1574, lr=1.63e-04
#     micro-batch 0: 4 seqs, max_len=6004, total_len=10577, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2963, total_len=7938, wall=3.8s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6804, total_len=17876, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7162, total_len=11406, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7291, total_len=11539, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7033, total_len=11367, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6103, total_len=10259, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6429, total_len=15262, wall=6.4s, peak=87.9GB, mem=77.8GB
#   step 47/244: loss:mean=0.007669, grad_norm=0.1606, lr=1.62e-04
#     micro-batch 0: 4 seqs, max_len=3822, total_len=9894, wall=4.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6715, total_len=14355, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=4462, total_len=10387, wall=4.8s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6965, total_len=13829, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7317, total_len=20143, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5567, total_len=13226, wall=5.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6722, total_len=13760, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7585, total_len=21364, wall=7.2s, peak=87.9GB, mem=77.8GB
#   step 48/244: loss:mean=0.004789, grad_norm=0.1106, lr=1.61e-04
#     micro-batch 0: 4 seqs, max_len=6352, total_len=12279, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7586, total_len=12149, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3291, total_len=9545, wall=4.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=4476, total_len=9594, wall=4.9s, peak=87.9GB, mem=77.7GB
#     micro-batch 4: 4 seqs, max_len=6306, total_len=11419, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5931, total_len=13860, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6370, total_len=12784, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2357, total_len=6919, wall=3.3s, peak=87.9GB, mem=77.6GB
#   step 49/244: loss:mean=0.006116, grad_norm=0.1710, lr=1.61e-04
#     micro-batch 0: 4 seqs, max_len=2650, total_len=6770, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=4561, total_len=10559, wall=5.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=6901, total_len=13241, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7106, total_len=15294, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6861, total_len=12739, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6820, total_len=21853, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7396, total_len=17135, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7282, total_len=15113, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 50/244: loss:mean=0.007914, grad_norm=0.1524, lr=1.60e-04
#     micro-batch 0: 4 seqs, max_len=4127, total_len=12425, wall=4.6s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=6523, total_len=12301, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6249, total_len=17849, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7016, total_len=14087, wall=7.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7386, total_len=16476, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7283, total_len=18332, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7181, total_len=16634, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=2188, total_len=7564, wall=3.3s, peak=87.9GB, mem=77.6GB
#   step 51/244: loss:mean=0.005409, grad_norm=0.1767, lr=1.59e-04
#     micro-batch 0: 4 seqs, max_len=7094, total_len=11434, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=5681, total_len=15840, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7251, total_len=16782, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6314, total_len=11310, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7427, total_len=21683, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7199, total_len=14896, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5703, total_len=14209, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7177, total_len=21988, wall=7.0s, peak=87.9GB, mem=77.8GB
#   step 52/244: loss:mean=0.007255, grad_norm=0.1314, lr=1.58e-04
#     micro-batch 0: 4 seqs, max_len=7166, total_len=16135, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2324, total_len=6141, wall=3.3s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=7464, total_len=16395, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6736, total_len=19270, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5845, total_len=8178, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5689, total_len=10923, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6838, total_len=17815, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6002, total_len=9973, wall=6.1s, peak=87.9GB, mem=77.8GB
#   step 53/244: loss:mean=0.005812, grad_norm=0.1543, lr=1.57e-04
#     micro-batch 0: 4 seqs, max_len=7185, total_len=15659, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6523, total_len=11815, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6228, total_len=13805, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7330, total_len=16946, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7054, total_len=17244, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=5112, total_len=13571, wall=5.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6972, total_len=13800, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7069, total_len=15359, wall=6.9s, peak=87.9GB, mem=77.8GB
#   step 54/244: loss:mean=0.006372, grad_norm=0.1724, lr=1.57e-04
#     micro-batch 0: 4 seqs, max_len=2692, total_len=9174, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=5736, total_len=11851, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6723, total_len=17960, wall=6.6s, peak=87.9GB, mem=77.8GB
# ...
#     micro-batch 6: 4 seqs, max_len=4680, total_len=13152, wall=5.0s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=7614, total_len=14992, wall=7.3s, peak=87.9GB, mem=77.8GB
#   step 225/244: loss:mean=0.002192, grad_norm=0.0394, lr=1.64e-05
#     micro-batch 0: 4 seqs, max_len=6103, total_len=11755, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6662, total_len=21082, wall=7.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7109, total_len=15583, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7005, total_len=22871, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6606, total_len=17682, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=2532, total_len=7723, wall=3.4s, peak=87.9GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=7247, total_len=19238, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3275, total_len=9175, wall=4.0s, peak=87.9GB, mem=77.7GB
#   step 226/244: loss:mean=0.002152, grad_norm=0.0211, lr=1.56e-05
#     micro-batch 0: 4 seqs, max_len=7017, total_len=19776, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2640, total_len=8375, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=6864, total_len=17143, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7162, total_len=17936, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5981, total_len=18845, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7367, total_len=17329, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6487, total_len=13487, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7034, total_len=15100, wall=6.9s, peak=87.9GB, mem=77.8GB
#   step 227/244: loss:mean=0.002226, grad_norm=0.0222, lr=1.48e-05
#     micro-batch 0: 4 seqs, max_len=2747, total_len=7997, wall=3.6s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=5765, total_len=12070, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7404, total_len=15470, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6442, total_len=16080, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=4026, total_len=9085, wall=4.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=7466, total_len=19403, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5942, total_len=13389, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6701, total_len=11906, wall=6.6s, peak=87.9GB, mem=77.8GB
#   step 228/244: loss:mean=0.001960, grad_norm=0.0162, lr=1.39e-05
#     micro-batch 0: 4 seqs, max_len=6907, total_len=16579, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=2396, total_len=8673, wall=3.3s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=2878, total_len=10037, wall=3.7s, peak=87.9GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6994, total_len=16519, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3891, total_len=8675, wall=4.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6740, total_len=22964, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7142, total_len=12536, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7240, total_len=18483, wall=7.0s, peak=87.9GB, mem=77.8GB
#   step 229/244: loss:mean=0.002181, grad_norm=0.0443, lr=1.31e-05
#     micro-batch 0: 4 seqs, max_len=2318, total_len=6153, wall=3.3s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=6153, total_len=16546, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5773, total_len=15786, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5988, total_len=13755, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6914, total_len=12684, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6197, total_len=15688, wall=6.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=5696, total_len=10664, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3467, total_len=7801, wall=4.1s, peak=87.9GB, mem=77.7GB
#   step 230/244: loss:mean=0.001844, grad_norm=0.0245, lr=1.23e-05
#     micro-batch 0: 4 seqs, max_len=7431, total_len=18642, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7120, total_len=12711, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6057, total_len=10688, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6781, total_len=13964, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6642, total_len=16587, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3658, total_len=8754, wall=4.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6811, total_len=15476, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6610, total_len=16420, wall=6.5s, peak=87.9GB, mem=77.8GB
#   step 231/244: loss:mean=0.002112, grad_norm=0.0417, lr=1.15e-05
#     micro-batch 0: 4 seqs, max_len=2699, total_len=9190, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=2013, total_len=4960, wall=3.2s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=7471, total_len=17330, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7546, total_len=12139, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7052, total_len=15079, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7294, total_len=15624, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7231, total_len=16772, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=5734, total_len=12348, wall=5.9s, peak=87.9GB, mem=77.8GB
#   step 232/244: loss:mean=0.002102, grad_norm=0.0320, lr=1.07e-05
#     micro-batch 0: 4 seqs, max_len=7466, total_len=17265, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7411, total_len=11078, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=2315, total_len=4950, wall=3.3s, peak=87.9GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=6841, total_len=17738, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5635, total_len=10586, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=3649, total_len=10316, wall=4.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6499, total_len=16963, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6226, total_len=12563, wall=6.3s, peak=87.9GB, mem=77.8GB
#   step 233/244: loss:mean=0.001998, grad_norm=0.0141, lr=9.84e-06
#     micro-batch 0: 4 seqs, max_len=6871, total_len=11509, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6955, total_len=22224, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7170, total_len=24937, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6322, total_len=10617, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7320, total_len=11987, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7443, total_len=23223, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6966, total_len=15964, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6939, total_len=14364, wall=6.8s, peak=87.9GB, mem=77.8GB
#   step 234/244: loss:mean=0.002467, grad_norm=0.0430, lr=9.02e-06
#     micro-batch 0: 4 seqs, max_len=6722, total_len=14472, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7140, total_len=12758, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7352, total_len=22960, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6724, total_len=16332, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5947, total_len=12487, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6468, total_len=10941, wall=6.5s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=2373, total_len=6451, wall=3.3s, peak=87.9GB, mem=77.6GB
#     micro-batch 7: 4 seqs, max_len=6483, total_len=18671, wall=6.4s, peak=87.9GB, mem=77.8GB
#   step 235/244: loss:mean=0.002232, grad_norm=0.0224, lr=8.20e-06
#     micro-batch 0: 4 seqs, max_len=7610, total_len=14075, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7311, total_len=18295, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5652, total_len=10032, wall=5.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6254, total_len=14820, wall=6.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3429, total_len=6145, wall=5.1s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=6869, total_len=16043, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=6872, total_len=10769, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6710, total_len=13309, wall=6.6s, peak=87.9GB, mem=77.8GB
#   step 236/244: loss:mean=0.002184, grad_norm=0.0404, lr=7.38e-06
#     micro-batch 0: 4 seqs, max_len=7188, total_len=15258, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6914, total_len=22844, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=3991, total_len=9540, wall=4.5s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=6031, total_len=13886, wall=6.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2336, total_len=7043, wall=3.3s, peak=87.9GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=7571, total_len=18317, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7427, total_len=22813, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7269, total_len=22569, wall=7.0s, peak=87.9GB, mem=77.8GB
#   step 237/244: loss:mean=0.002130, grad_norm=0.0175, lr=6.56e-06
#     micro-batch 0: 4 seqs, max_len=4795, total_len=14435, wall=5.1s, peak=87.9GB, mem=77.7GB
#     micro-batch 1: 4 seqs, max_len=5919, total_len=13834, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=5912, total_len=13483, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7310, total_len=16669, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7504, total_len=16928, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6935, total_len=12758, wall=6.8s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7298, total_len=20707, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3784, total_len=11397, wall=4.3s, peak=87.9GB, mem=77.7GB
#   step 238/244: loss:mean=0.001953, grad_norm=0.0142, lr=5.74e-06
#     micro-batch 0: 4 seqs, max_len=3106, total_len=8570, wall=3.8s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=2758, total_len=8082, wall=3.6s, peak=87.9GB, mem=77.6GB
#     micro-batch 2: 4 seqs, max_len=7101, total_len=18742, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6768, total_len=17672, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7126, total_len=17639, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=6630, total_len=13524, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=3830, total_len=8080, wall=4.4s, peak=87.9GB, mem=77.7GB
#     micro-batch 7: 4 seqs, max_len=6968, total_len=12071, wall=6.8s, peak=87.9GB, mem=77.8GB
#   step 239/244: loss:mean=0.002382, grad_norm=0.0281, lr=4.92e-06
#     micro-batch 0: 4 seqs, max_len=5734, total_len=11268, wall=5.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=6712, total_len=12758, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7298, total_len=20905, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=7239, total_len=22724, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=6655, total_len=14275, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7668, total_len=19098, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7266, total_len=12398, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=7387, total_len=22203, wall=7.1s, peak=87.9GB, mem=77.8GB
#   step 240/244: loss:mean=0.002098, grad_norm=0.0441, lr=4.10e-06
#     micro-batch 0: 4 seqs, max_len=7195, total_len=13110, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=7078, total_len=13612, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=7593, total_len=19493, wall=7.3s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=6771, total_len=16075, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=2444, total_len=6166, wall=3.4s, peak=87.9GB, mem=77.6GB
#     micro-batch 5: 4 seqs, max_len=7101, total_len=22944, wall=7.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7433, total_len=18220, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=6000, total_len=10230, wall=6.1s, peak=87.9GB, mem=77.8GB
#   step 241/244: loss:mean=0.002075, grad_norm=0.0191, lr=3.28e-06
#     micro-batch 0: 4 seqs, max_len=2277, total_len=4135, wall=3.2s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=6768, total_len=17593, wall=6.7s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=6676, total_len=16218, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 3: 4 seqs, max_len=5935, total_len=11400, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=5926, total_len=14575, wall=6.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=2534, total_len=6427, wall=3.4s, peak=87.9GB, mem=77.6GB
#     micro-batch 6: 4 seqs, max_len=7039, total_len=19623, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3455, total_len=8855, wall=4.1s, peak=87.9GB, mem=77.7GB
#   step 242/244: loss:mean=0.002114, grad_norm=0.0261, lr=2.46e-06
#     micro-batch 0: 4 seqs, max_len=2985, total_len=10240, wall=3.7s, peak=87.9GB, mem=77.6GB
#     micro-batch 1: 4 seqs, max_len=7517, total_len=21344, wall=7.2s, peak=87.9GB, mem=77.8GB
#     micro-batch 2: 4 seqs, max_len=2556, total_len=8294, wall=3.5s, peak=87.9GB, mem=77.6GB
#     micro-batch 3: 4 seqs, max_len=7171, total_len=17716, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=7084, total_len=17932, wall=6.9s, peak=87.9GB, mem=77.8GB
#     micro-batch 5: 4 seqs, max_len=7191, total_len=18944, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 6: 4 seqs, max_len=7363, total_len=12284, wall=7.1s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3717, total_len=10250, wall=4.3s, peak=87.9GB, mem=77.7GB
#   step 243/244: loss:mean=0.002223, grad_norm=0.0436, lr=1.64e-06
#     micro-batch 0: 4 seqs, max_len=6663, total_len=12208, wall=6.6s, peak=87.9GB, mem=77.8GB
#     micro-batch 1: 4 seqs, max_len=4423, total_len=10590, wall=4.9s, peak=87.9GB, mem=77.7GB
#     micro-batch 2: 4 seqs, max_len=3380, total_len=10915, wall=4.1s, peak=87.9GB, mem=77.7GB
#     micro-batch 3: 4 seqs, max_len=7199, total_len=22454, wall=7.0s, peak=87.9GB, mem=77.8GB
#     micro-batch 4: 4 seqs, max_len=3643, total_len=8273, wall=4.2s, peak=87.9GB, mem=77.7GB
#     micro-batch 5: 4 seqs, max_len=3794, total_len=10272, wall=4.3s, peak=87.9GB, mem=77.7GB
#     micro-batch 6: 4 seqs, max_len=6394, total_len=13398, wall=6.4s, peak=87.9GB, mem=77.8GB
#     micro-batch 7: 4 seqs, max_len=3895, total_len=9210, wall=4.4s, peak=87.9GB, mem=77.7GB
#   step 244/244: loss:mean=0.002155, grad_norm=0.0718, lr=8.20e-07
#
# Training complete. Peak VRAM: 87.9 GB
# /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:279: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# Wrote submission.zip
# Training complete.
